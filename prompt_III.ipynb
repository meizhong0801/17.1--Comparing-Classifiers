# %% [markdown]
# # Practical Application III: Comparing Classifiers
#
# **Overview**: In this practical application, your goal is to compare the performance of the classifiers we encountered in this section, namely K Nearest Neighbor, Logistic Regression, Decision Trees, and Support Vector Machines.  We will utilize a dataset related to marketing bank products over the telephone.

# %% [markdown]
# ### Getting Started
#
# Our dataset comes from the UCI Machine Learning repository [link](https://archive.ics.uci.edu/ml/datasets/bank+marketing).  The data is from a Portugese banking institution and is a collection of the results of multiple marketing campaigns.  We will make use of the article accompanying the dataset [here](CRISP-DM-BANK.pdf) for more information on the data and features.

# %% [markdown]
# ### Problem 1: Understanding the Data
#
# To gain a better understanding of the data, please read the information provided in the UCI link above, and examine the **Materials and Methods** section of the paper.  How many marketing campaigns does this data represent?

# %%
17
# Out:
# 17

# %% [markdown]
# ### Problem 2: Read in the Data
#
# Use pandas to read in the dataset `bank-additional-full.csv` and assign to a meaningful variable name.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('data/bank-additional-full.csv', sep = ';')

# %%
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %% [markdown]
# ### Problem 3: Understanding the Features
#
#
# Examine the data description below, and determine if any of the features are missing values or need to be coerced to a different data type.
#
#
# ```
# Input variables:
# # bank client data:
# 1 - age (numeric)
# 2 - job : type of job (categorical: 'admin.','blue-collar','entrepreneur','housemaid','management','retired','self-employed','services','student','technician','unemployed','unknown')
# 3 - marital : marital status (categorical: 'divorced','married','single','unknown'; note: 'divorced' means divorced or widowed)
# 4 - education (categorical: 'basic.4y','basic.6y','basic.9y','high.school','illiterate','professional.course','university.degree','unknown')
# 5 - default: has credit in default? (categorical: 'no','yes','unknown')
# 6 - housing: has housing loan? (categorical: 'no','yes','unknown')
# 7 - loan: has personal loan? (categorical: 'no','yes','unknown')
# # related with the last contact of the current campaign:
# 8 - contact: contact communication type (categorical: 'cellular','telephone')
# 9 - month: last contact month of year (categorical: 'jan', 'feb', 'mar', ..., 'nov', 'dec')
# 10 - day_of_week: last contact day of the week (categorical: 'mon','tue','wed','thu','fri')
# 11 - duration: last contact duration, in seconds (numeric). Important note: this attribute highly affects the output target (e.g., if duration=0 then y='no'). Yet, the duration is not known before a call is performed. Also, after the end of the call y is obviously known. Thus, this input should only be included for benchmark purposes and should be discarded if the intention is to have a realistic predictive model.
# # other attributes:
# 12 - campaign: number of contacts performed during this campaign and for this client (numeric, includes last contact)
# 13 - pdays: number of days that passed by after the client was last contacted from a previous campaign (numeric; 999 means client was not previously contacted)
# 14 - previous: number of contacts performed before this campaign and for this client (numeric)
# 15 - poutcome: outcome of the previous marketing campaign (categorical: 'failure','nonexistent','success')
# # social and economic context attributes
# 16 - emp.var.rate: employment variation rate - quarterly indicator (numeric)
# 17 - cons.price.idx: consumer price index - monthly indicator (numeric)
# 18 - cons.conf.idx: consumer confidence index - monthly indicator (numeric)
# 19 - euribor3m: euribor 3 month rate - daily indicator (numeric)
# 20 - nr.employed: number of employees - quarterly indicator (numeric)
#
# Output variable (desired target):
# 21 - y - has the client subscribed a term deposit? (binary: 'yes','no')
# ```

# %%
# determine if any of the features are missing values
df.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %% [markdown]
# ### Problem 4: Understanding the Task
#
# After examining the description and data, your goal now is to clearly state the *Business Objective* of the task.  State the objective below.

# %% [markdown]
# ## Compare the performance of the classifiers we encountered in this section, namely K Nearest Neighbor, Logistic Regression, Decision Trees, and Support Vector Machines.

# %% [markdown]
# ### Problem 5: Engineering Features
#
# Now that you understand your business objective, we will build a basic model to get started.  Before we can do this, we must work to encode the data.  Using just the bank information features, prepare the features and target column for modeling with appropriate encoding and transformations.

# %%
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
# Convert target column to numrical
df["y"] = df["y"].map({'no':0, 'yes':1})
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
# Categorical columns
string_col = df.select_dtypes(include="object").columns
string_col
# Out:
# Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'day_of_week', 'poutcome'],
#       dtype='object')

# %%
## Createing one hot encoded features for working with non tree based algorithms 
df_nontree=pd.get_dummies(df,columns=string_col,drop_first=False)
df_nontree.head()
# Out:
#    age  duration  campaign  pdays  previous  emp.var.rate  cons.price.idx  \
# 0   56       261         1    999         0           1.1          93.994
# 1   57       149         1    999         0           1.1          93.994
# 2   37       226         1    999         0           1.1          93.994
# 3   40       151         1    999         0           1.1          93.994
# 4   56       307         1    999         0           1.1          93.994
#
#    cons.conf.idx  euribor3m  nr.employed  ...  month_oct  month_sep  \
# 0          -36.4      4.857       5191.0  ...      False      False
# 1          -36.4      4.857       5191.0  ...      False      False
# 2          -36.4      4.857       5191.0  ...      False      False
# 3          -36.4      4.857       5191.0  ...      False      False
# 4          -36.4      4.857       5191.0  ...      False      False
#
#    day_of_week_fri  day_of_week_mon  day_of_week_thu  day_of_week_tue  \
# ...

# %%
## Create label encoder features for working with tree based algorithms
from sklearn.preprocessing import LabelEncoder

df_tree = df.apply(LabelEncoder().fit_transform)
df_tree.head()
# Out:
#    age  job  marital  education  default  housing  loan  contact  month  \
# 0   39    3        1          0        0        0     0        1      6
# 1   40    7        1          3        1        0     0        1      6
# 2   20    7        1          3        0        2     0        1      6
# 3   23    0        1          1        0        0     0        1      6
# 4   39    7        1          3        0        0     2        1      6
#
#    day_of_week  ...  campaign  pdays  previous  poutcome  emp.var.rate  \
# 0            1  ...         0     26         0         1             8
# 1            1  ...         0     26         0         1             8
# 2            1  ...         0     26         0         1             8
# 3            1  ...         0     26         0         1             8
# 4            1  ...         0     26         0         1             8
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed  y
# ...

# %% [markdown]
# ### Problem 6: Train/Test Split
#
# With your data prepared, split it into a train and test set.

# %%
X = df_nontree[[col for col in df_nontree.columns if col != "y"]]
y = df_nontree["y"]

# %%
X.head()
# Out:
#    age  duration  campaign  pdays  previous  emp.var.rate  cons.price.idx  \
# 0   56       261         1    999         0           1.1          93.994
# 1   57       149         1    999         0           1.1          93.994
# 2   37       226         1    999         0           1.1          93.994
# 3   40       151         1    999         0           1.1          93.994
# 4   56       307         1    999         0           1.1          93.994
#
#    cons.conf.idx  euribor3m  nr.employed  ...  month_oct  month_sep  \
# 0          -36.4      4.857       5191.0  ...      False      False
# 1          -36.4      4.857       5191.0  ...      False      False
# 2          -36.4      4.857       5191.0  ...      False      False
# 3          -36.4      4.857       5191.0  ...      False      False
# 4          -36.4      4.857       5191.0  ...      False      False
#
#    day_of_week_fri  day_of_week_mon  day_of_week_thu  day_of_week_tue  \
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
X_train.shape
X_test.shape
# Out:
# (10297, 63)

# %%
X_tree = df_tree[[col for col in df_tree.columns if col != "y"]]
y_tree = df_tree["y"]

X_tree_train, X_tree_test, y_tree_train, y_tree_test = train_test_split(X_tree, y_tree)

# %% [markdown]
# ### Problem 7: A Baseline Model
#
# Before we build our first model, we want to establish a baseline.  What is the baseline performance that our classifier should aim to beat?

# %%
y = df["y"]
baseline_accuracy = (y == y.mode()[0]).mean()
print(f"Baseline accuracy: {baseline_accuracy:.2f}")
# Out:
# Baseline accuracy: 0.89

# %% [markdown]
# ### Problem 8: A Simple Model
#
# Use Logistic Regression to build a basic model on your data.

# %%
from sklearn.linear_model import LogisticRegression

clf=LogisticRegression()
clf.fit(X_train,y_train)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95      9151
#            1       0.69      0.40      0.51      1146
#
#     accuracy                           0.91     10297
#    macro avg       0.81      0.69      0.73     10297
# weighted avg       0.90      0.91      0.90     10297
#
# AUC Score: 0.6904235472982574
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# ### Problem 9: Score the Model
#
# What is the accuracy of your model?

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score,roc_auc_score

y_pred = clf.predict(X_test)
print(classification_report(y_test,y_pred))
auc=roc_auc_score(y_test,y_pred)
print(f"AUC Score: {auc:.4f}")
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.4f}")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95      9151
#            1       0.69      0.40      0.51      1146
#
#     accuracy                           0.91     10297
#    macro avg       0.81      0.69      0.73     10297
# weighted avg       0.90      0.91      0.90     10297
#
# AUC Score: 0.6904
# Accuracy: 0.9131

# %% [markdown]
# ### Problem 10: Model Comparisons
#
# Now, we aim to compare the performance of the Logistic Regression model to our KNN algorithm, Decision Tree, and SVM models.  Using the default settings for each of the models, fit and score each.  Also, be sure to compare the fit time of each of the models.  Present your findings in a `DataFrame` similar to that below:
#
# | Model | Train Time | Train Accuracy | Test Accuracy |
# | ----- | ---------- | -------------  | -----------   |
# |     |    |.     |.     |

# %%
## KNN
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_tree_train,y_tree_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred_knn = knn.predict(X_tree_test)
print(classification_report(y_tree_test,y_pred_knn))
auc_knn=roc_auc_score(y_tree_test,y_pred_knn)
print(f"AUC Score: {auc_knn:.4f}")
accuracy_knn = accuracy_score(y_tree_test, y_pred_knn)
print(f"Accuracy: {accuracy_knn:.4f}")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95      9145
#            1       0.58      0.49      0.53      1152
#
#     accuracy                           0.90     10297
#    macro avg       0.76      0.72      0.74     10297
# weighted avg       0.90      0.90      0.90     10297
#
# AUC Score: 0.7202
# Accuracy: 0.9026

# %%
## Decision Tree
from sklearn.tree import DecisionTreeClassifier

dtree = DecisionTreeClassifier()
dtree.fit(X_tree_train,y_tree_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred_dtree = dtree.predict(X_tree_test)
print(classification_report(y_tree_test,y_pred_dtree))
auc_dtree=roc_auc_score(y_tree_test,y_pred_dtree)
print(f"AUC Score: {auc_dtree:.4f}")
accuracy_dtree = accuracy_score(y_tree_test, y_pred_dtree)
print(f"Accuracy: {accuracy_dtree:.4f}")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.93      0.94      9145
#            1       0.50      0.54      0.52      1152
#
#     accuracy                           0.89     10297
#    macro avg       0.72      0.74      0.73     10297
# weighted avg       0.89      0.89      0.89     10297
#
# AUC Score: 0.7385
# Accuracy: 0.8893

# %%
from sklearn.svm import SVC

model = SVC(kernel='rbf', probability=True)  
model.fit(X_train, y_train)
# Out:
# SVC(probability=True)

# %%
y_pred_svc = model.predict(X_test)
print(classification_report(y_test,y_pred_svc))
auc_svc=roc_auc_score(y_test,y_pred_svc)
print(f"AUC Score: {auc_svc:.4f}")
accuracy_svc = accuracy_score(y_test, y_pred_svc)
print(f"Accuracy: {accuracy_svc:.4f}")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94      9201
#            1       0.00      0.00      0.00      1096
#
#     accuracy                           0.89     10297
#    macro avg       0.45      0.50      0.47     10297
# weighted avg       0.80      0.89      0.84     10297
#
# AUC Score: 0.5000
# Accuracy: 0.8936
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %% [markdown]
# ### Problem 11: Improving the Model
#
# Now that we have some basic models on the board, we want to try to improve these.  Below, we list a few things to explore in this pursuit.
#
# - More feature engineering and exploration.  For example, should we keep the gender feature?  Why or why not?
# - Hyperparameter tuning and grid search.  All of our models have additional hyperparameters to tune and explore.  For example the number of neighbors in KNN or the maximum depth of a Decision Tree.
# - Adjust your performance metric

# %%
## Feature scaling

from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

scaled_array = scaler.fit_transform(X)
X_scaled = pd.DataFrame(X, columns=X.columns)
X_scaled.head()
# Out:
#    age  duration  campaign  pdays  previous  emp.var.rate  cons.price.idx  \
# 0   56       261         1    999         0           1.1          93.994
# 1   57       149         1    999         0           1.1          93.994
# 2   37       226         1    999         0           1.1          93.994
# 3   40       151         1    999         0           1.1          93.994
# 4   56       307         1    999         0           1.1          93.994
#
#    cons.conf.idx  euribor3m  nr.employed  ...  month_oct  month_sep  \
# 0          -36.4      4.857       5191.0  ...      False      False
# 1          -36.4      4.857       5191.0  ...      False      False
# 2          -36.4      4.857       5191.0  ...      False      False
# 3          -36.4      4.857       5191.0  ...      False      False
# 4          -36.4      4.857       5191.0  ...      False      False
#
#    day_of_week_fri  day_of_week_mon  day_of_week_thu  day_of_week_tue  \
# ...

# %%
X_scaled_train, X_scaled_test, y_train, y_test = train_test_split(X, y)

# %%
model1 = SVC(kernel='rbf', probability=True)  
model1.fit(X_scaled_train, y_train)
# Out:
# SVC(probability=True)

# %%
y_pred_svc1 = model1.predict(X_test)
print(classification_report(y_test,y_pred_svc1))
auc_svc1=roc_auc_score(y_test,y_pred_svc1)
print(f"AUC Score: {auc_svc1:.4f}")
accuracy_svc1 = accuracy_score(y_test, y_pred_svc)
print(f"Accuracy: {accuracy_svc1:.4f}")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.96      0.93      9201
#            1       0.12      0.04      0.06      1096
#
#     accuracy                           0.87     10297
#    macro avg       0.51      0.50      0.49     10297
# weighted avg       0.81      0.87      0.84     10297
#
# AUC Score: 0.5024
# Accuracy: 0.8656

# %%
from sklearn.model_selection import GridSearchCV

# 2. Define parameter grid
param_grid = {
    'C': [0.1, 1, 10],
    'gamma': [0.01, 0.1, 1],
    'kernel': ['rbf']  # can add 'linear', 'poly' if you want
}

grid = GridSearchCV(SVC(), param_grid, cv=5, scoring='accuracy')
grid.fit(X_train, y_train)

# 4. Print best parameters and test performance
print("Best Parameters:", grid.best_params_)
# Out:
# Best Parameters: {'C': 0.1, 'gamma': 0.01, 'kernel': 'rbf'}

# %%
y_pred = grid.predict(X_test)
print("\nClassification Report on Test Set:")
print(classification_report(y_test, y_pred))
auc=roc_auc_score(y_test,y_pred)
print(f"AUC Score: {auc:.4f}")
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.4f}")
# Out:
# Classification Report on Test Set:
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94      9201
#            1       0.00      0.00      0.00      1096
#
#     accuracy                           0.89     10297
#    macro avg       0.45      0.50      0.47     10297
# weighted avg       0.80      0.89      0.84     10297
#
# AUC Score: 0.5000
# Accuracy: 0.8936
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %% [markdown]
# ##### Questions
